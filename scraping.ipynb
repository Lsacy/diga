# %%
import time 
import re
import pandas as pd 
from selenium import webdriver 
from selenium.webdriver import Chrome 
from selenium.webdriver.chrome.service import Service 
from selenium.webdriver.common.by import By 
from webdriver_manager.chrome import ChromeDriverManager

# start by defining the options 
options = webdriver.ChromeOptions() 
options.headless = True # it's more scalable to work in headless mode 
# normally, selenium waits for all resources to download 
# we don't need it as the page also populated with the running javascript code. 
options.page_load_strategy = 'none' 
# this returns the path web driver downloaded 
chrome_path = ChromeDriverManager().install() 
chrome_service = Service(chrome_path) 
# pass the defined options and service objects to initialize the web driver 
driver = Chrome(options=options, service=chrome_service) 
driver.implicitly_wait(5)

# import beautiful soup
from bs4 import BeautifulSoup
from sentence_transformers import SentenceTransformer

# %%
page = 'https://diga.bfarm.de/de/verzeichnis'
driver.get(page) 
time.sleep(3)
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
links = soup.find_all('a', class_='ember-view entity-app__button')
for i,j in enumerate(links):
    full_link = 'https://diga.bfarm.de' + j.get('href')
    links[i] = full_link
print(links)
# Out:
# ['https://diga.bfarm.de/de/verzeichnis/00961', 'https://diga.bfarm.de/de/verzeichnis/01346', 'https://diga.bfarm.de/de/verzeichnis/00998', 'https://diga.bfarm.de/de/verzeichnis/00450', 'https://diga.bfarm.de/de/verzeichnis/01815', 'https://diga.bfarm.de/de/verzeichnis/00419', 'https://diga.bfarm.de/de/verzeichnis/01254', 'https://diga.bfarm.de/de/verzeichnis/01734', 'https://diga.bfarm.de/de/verzeichnis/01376', 'https://diga.bfarm.de/de/verzeichnis/01513', 'https://diga.bfarm.de/de/verzeichnis/01304', 'https://diga.bfarm.de/de/verzeichnis/01772', 'https://diga.bfarm.de/de/verzeichnis/00965', 'https://diga.bfarm.de/de/verzeichnis/01497', 'https://diga.bfarm.de/de/verzeichnis/00300', 'https://diga.bfarm.de/de/verzeichnis/01329', 'https://diga.bfarm.de/de/verzeichnis/00350', 'https://diga.bfarm.de/de/verzeichnis/01282', 'https://diga.bfarm.de/de/verzeichnis/00993', 'https://diga.bfarm.de/de/verzeichnis/01496', 'https://diga.bfarm.de/de/verzeichnis/00329', 'https://diga.bfarm.de/de/verzeichnis/01196', 'https://diga.bfarm.de/de/verzeichnis/01085', 'https://diga.bfarm.de/de/verzeichnis/01110', 'https://diga.bfarm.de/de/verzeichnis/01613', 'https://diga.bfarm.de/de/verzeichnis/00872', 'https://diga.bfarm.de/de/verzeichnis/01464', 'https://diga.bfarm.de/de/verzeichnis/00474', 'https://diga.bfarm.de/de/verzeichnis/00876', 'https://diga.bfarm.de/de/verzeichnis/01049', 'https://diga.bfarm.de/de/verzeichnis/01775', 'https://diga.bfarm.de/de/verzeichnis/00508', 'https://diga.bfarm.de/de/verzeichnis/00316', 'https://diga.bfarm.de/de/verzeichnis/00746', 'https://diga.bfarm.de/de/verzeichnis/00387', 'https://diga.bfarm.de/de/verzeichnis/00868', 'https://diga.bfarm.de/de/verzeichnis/00294']

# %%
# create dataframe with following columns
columns = 'app_name, developer_info, website_info, app_status, start_date, end_date, app_description, indication_codes, indication_names, price, property_values'
columns = columns.split(', ')
df = pd.DataFrame(columns=columns)

# %%
for link in links:
    # connect to a link
    driver.get(link)
    time.sleep(2)

    # find the button with more indications listed
    more_info_divs = driver.find_elements(By.CLASS_NAME, 'entity-app__info__more')
    more_info_div = more_info_divs[1]
    # click on the button called 'mehr erfahren'
    button = more_info_div.find_element(By.TAG_NAME, 'button')
    button.click()

    # get the html code
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    ## find app header information
    # Find the div element with the class "entity-app__header"
    header_div = soup.find('div', class_='entity-app__header')
    # Extract the app name
    app_name = header_div.find('h1', class_='entity-app__header__name').text.strip()
    # Extract the app developer and website information
    subheader = header_div.find('div', class_='entity-app__subheader')
    developer_info = subheader.find_all('span')[0].text.strip()
    website_info = subheader.find_all('a')[0].text.strip()

    ## find app status information
    # Find the div element with the class "entity-app__app-type"
    app_type_div = soup.find('div', class_='entity-app__app-type')
    # Extract the app status
    app_status = app_type_div.find('span').text.strip()
    # if app_status contains text 'vorläufig', then check for the date
    if 'Vorläufig' in app_status:
        # set status to 'vorläufig'
        app_status = 'vorläufig aufgenommen'
        # Extract the duration of the app type
        duration_text = app_type_div.find('small').text.strip()
        # remove ( from text
        start_date = duration_text.split('bis')[0].strip().replace('(', '')
        end_date = duration_text.split('bis')[1].strip().replace(')', '')
    else:
        start_date = None
        end_date = None


    ## find app description
    app_description = soup.find('div', class_='entity-app__summary').text.strip()

    ## find platform information
    # Find all of the div elements with the class "entity-app__info__list" within the info div
    list_divs = soup.find_all('div', class_='entity-app__info__list')

    platform_div = None
    application_div = None
    properties_div = None

    # Find the div element for each type of information
    for div in list_divs:
        header = div.find('div', class_='entity-app__info__list__header')
        if header:
            header_text = header.text.strip()
            if header_text == 'Plattformen':
                platform_div = div
            elif header_text == 'Anzuwenden bei':
                application_div = div
            elif header_text == 'Eigenschaften':
                properties_div = div

    # Extract the platform information
    platform_items = platform_div.find('div', class_='entity-app__info__list__items')
    platform_values = platform_items.find_all('div', class_='entity-app__info__list__items__value')
    platform_values = [i.text.strip() for i in platform_values]
    platform_values

    # Extract the application / indication / usage area information
    applications = soup.find('div', class_='modal-information__content__inner')
    applications = applications.find('div', class_='entity-app-answers__questions__answer')
    applications = applications.find('p')
    applications = str(applications).split('<br/>')
    applications
    indication_codes = []
    indication_names = []
    for i in applications:
        i = str(i).replace('<p>', '').replace('</p>', '')
        indication_codes.append(i.split(' ')[0])
        indication_names.append(i.split(' ', 1)[1])

    
    # Extract the properties information
    properties = {}
    properties_items = properties_div.find('div', class_='entity-app__info__list__items')
    property_values = properties_items.find_all('div', class_='entity-app__info__list__items__value')
    property_values = [i.text.strip() for i in property_values]
    # extract the numbers
    price = re.findall(r'\d{2,},\d{2}', property_values[0])
    if len(price) == 2:
        price1 = price[0].replace(',', '.')
        price2 = price[1].replace(',', '.')
        price = price1 + ' - ' + price2
    else:
        price = price[0].replace(',', '.')

    property_values = property_values[1:]
    df.loc[len(df)] = [app_name, developer_info, website_info, app_status, start_date, end_date, app_description, indication_codes, indication_names, price, property_values]

df
# Out:
# ['399,84']
# ['718,20']
# ['345,10']
# ['210,00']
# ['178,50', '357,00']
# 178.50
# <class 'str'>
# ['243,00']
# ['535,49']
# ['598,95']
# ['222,99']
# ['599,00']
# ['599,00']
# ['599,00']
# ['235,00']
# ['599,00']
# ['620,00']
# ['415,00']
# ['189,00']
# ['656,88']
# ['119,00']
# ['449,00']
# ['576,00']
# ['487,90']
# ['119,00', '329,00']
# 119.00
# <class 'str'>
# ['249,00']
# ['952,00']
# ['426,96']
# ['535,50']
# ['784,21']
# ['217,18']
# ['479,52']
# ['690,00']
# ['224,99']
# ['230,00']
# ['499,80']
# ['239,96']
# ['192,01']
# ['499,80']
#                                              app_name  \
# 0                              CANKADO PRO-React Onco
# 1                              Cara Care für Reizdarm
# 2   companion patella powered by medi - proved by ...
# 3                                            deprexis
# 4                                    edupression.com®
# 5                                             elevida
# 6                            elona therapy Depression
# 7                                            Endo-App
# 8                 HelloBetter Diabetes und Depression
# 9                                   HelloBetter Panik
# 10         HelloBetter ratiopharm chronischer Schmerz
# 11                               HelloBetter Schlafen
# 12                     HelloBetter Stress und Burnout
# 13                        HelloBetter Vaginismus Plus
# 14                  Invirto- Die Therapie gegen Angst
# 15              Kaia COPD: Meine aktive COPD Therapie
# 16                                            Kalmeda
# 17                                       Kranus Edera
# 18                                            Mawendo
# 19  Meine Tinnitus App - Das digitale Tinnitus Cou...
# 20             Mindable: Panikstörung und Agoraphobie
# 21                                   neolexon Aphasie
# 22                             NichtraucherHelden-App
# 23                    Novego: Depressionen bewältigen
# 24                                           optimune
# 25                        Oviva Direkt für Adipositas
# 26                                        PINK! Coach
# 27                                            re.flex
# 28                Selfapys Online-Kurs bei Depression
# 29  Selfapys Online-Kurs bei Generalisierter Angst...
# 30                    sinCephalea - Migräneprophylaxe
# 31                                             somnio
# 32                                            velibra
# 33                                            Vitadio
# 34                                             Vivira
# 35                                            vorvida
# 36                                            zanadio
#
#                                        developer_info  \
# 0                           CANKADO GmbH, Deutschland
# 1                HiDoc Technologies GmbH, Deutschland
# 2                           PrehApp GmbH, Deutschland
# 3                                GAIA AG, Deutschland
# 4                               SOFY GmbH, Österreich
# 5                                GAIA AG, Deutschland
# 6                      Elona Health GmbH, Deutschland
# 7                       Endo Health GmbH, Deutschland
# 8   GET.ON Institut für Online Gesundheitstraining...
# 9   GET.ON Institut für Online Gesundheitstraining...
# 10  GET.ON Institut für Online Gesundheitstraining...
# 11  GET.ON Institut für Online Gesundheitstraining...
# 12  GET.ON Institut für Online Gesundheitstraining...
# 13  GET.ON Institut für Online Gesundheitstraining...
# 14                       Sympatient GmbH, Deutschland
# 15             kaia health software GmbH, Deutschland
# 16                          mynoise GmbH, Deutschland
# 17                    Kranus Health GmbH, Deutschland
# 18                          Mawendo GmbH, Deutschland
# 19                         Sonormed GmbH, Deutschland
# 20                  Mindable Health GmbH, Deutschland
# 21                          Limedix GmbH, Deutschland
# 22               NichtraucherHelden GmbH, Deutschland
# 23                      IVPNetworks GmbH, Deutschland
# 24                               GAIA AG, Deutschland
# 25  Oviva AG (Zweigniederlassung Deutschland) , De...
# 26            PINK gegen Brustkrebs GmbH, Deutschland
# 27                    Kineto Tech Rehab SRL, Rumänien
# 28                          Selfapy GmbH, Deutschland
# 29                          Selfapy GmbH, Deutschland
# 30                          Perfood GmbH, Deutschland
# 31                      mementor DE GmbH, Deutschland
# 32                               GAIA AG, Deutschland
# 33                         Vitadio s.r.o., Tschechien
# 34                Vivira Health Lab GmbH, Deutschland
# 35                               GAIA AG, Deutschland
# 36                          aidhere GmbH, Deutschland
#
#                                          website_info             app_status  \
# 0                         partners.cankado.com/about/  vorläufig aufgenommen
# 1                                 cara.care/de/about/  vorläufig aufgenommen
# 2                                          prehapp.de  vorläufig aufgenommen
# 3                                  gaia-group.com/de/  Dauerhaft aufgenommen
# 4                                    edupression.com/  vorläufig aufgenommen
# 5                                  gaia-group.com/de/  Dauerhaft aufgenommen
# 6                                    www.elona.health  vorläufig aufgenommen
# 7                               diga.endometriose.app  vorläufig aufgenommen
# 8                                     hellobetter.de/  Dauerhaft aufgenommen
# 9                                     hellobetter.de/  Dauerhaft aufgenommen
# 10                                 www.hellobetter.de  vorläufig aufgenommen
# 11                                    hellobetter.de/  vorläufig aufgenommen
# 12                                    hellobetter.de/  Dauerhaft aufgenommen
# 13                                    hellobetter.de/  Dauerhaft aufgenommen
# 14                                     www.invirto.de  Dauerhaft aufgenommen
# 15                                     kaiahealth.de/  vorläufig aufgenommen
# 16                                     www.kalmeda.de  Dauerhaft aufgenommen
# 17                               www.kranushealth.com  vorläufig aufgenommen
# 18                                  diga.mawendo.com/  vorläufig aufgenommen
# 19                               www.sonormed.com/de/  vorläufig aufgenommen
# 20                                www.mindable.health  vorläufig aufgenommen
# 21                                       neolexon.de/  vorläufig aufgenommen
# 22                         www.nichtraucherhelden.de/  vorläufig aufgenommen
# 23                                www.ivpnetworks.de/  vorläufig aufgenommen
# 24                                 gaia-group.com/de/  vorläufig aufgenommen
# 25  oviva.com/de/de/oviva-direkt/rechtliche-hinweise/  vorläufig aufgenommen
# 26                             www.pink-brustkrebs.de  vorläufig aufgenommen
# 27                           www.sporlastic.de/reflex  vorläufig aufgenommen
# 28                                     www.selfapy.de  Dauerhaft aufgenommen
# 29                                    www.selfapy.com  Dauerhaft aufgenommen
# 30                                    www.perfood.de/  vorläufig aufgenommen
# 31                                    www.mementor.de  Dauerhaft aufgenommen
# 32                                 gaia-group.com/de/  Dauerhaft aufgenommen
# 33                                        vitadio.de/  vorläufig aufgenommen
# 34                                     www.vivira.com  Dauerhaft aufgenommen
# 35                                 gaia-group.com/de/  Dauerhaft aufgenommen
# 36                                        aidhere.de/  Dauerhaft aufgenommen
#
#     start_date    end_date                                    app_description  \
# 0   03.05.2021  02.05.2023  PRO-React Onco ist eine Web- und App-basierte ...
# 1   26.12.2021  25.11.2023  Cara Care für Reizdarm ist eine digitale Gesun...
# 2   04.10.2021  03.03.2023  companion patella powered by medi - proved by ...
# 3         None        None  deprexis ist ein interaktives onlinebasiertes ...
# 4   26.12.2022  25.08.2023  Die DiGA edupression.com® besteht aus dem Medi...
# 5         None        None  elevida ist eine digitale Gesundheitsanwendung...
# 6   26.12.2022  25.12.2023  elona therapy Depression ist die digitale Gesu...
# 7   09.10.2022  08.10.2023  Die Endo-App ist ein digitales Medizinprodukt ...
# 8         None        None  HelloBetter Diabetes und Depression ist ein in...
# 9         None        None  HelloBetter Panik ist ein interaktives psychol...
# 10  18.12.2021  17.07.2023  HelloBetter ratiopharm chronischer Schmerz ist...
# 11  18.12.2022  17.12.2023  HelloBetter Schlafen ist ein interaktives psyc...
# 12        None        None  HelloBetter Stress und Burnout ist ein interak...
# 13        None        None  HelloBetter Vaginismus Plus ist eine digitale ...
# 14        None        None  Invirto ermöglicht Menschen mit einer Agorapho...
# 15  26.12.2022  25.12.2023  Kaia COPD ist eine gemeinsam mit Lungenfachärz...
# 16        None        None  Diese DiGA bietet Patientinnen und Patienten (...
# 17  18.12.2021  17.04.2023  Kranus Edera ist eine digitale Gesundheitsanwe...
# 18  09.08.2021  08.08.2023  Mawendo stellt Trainingsprogramme mit Übungsvi...
# 19  06.03.2022  05.03.2023  Meine Tinnitus App - Das digitale Tinnitus Cou...
# 20  29.04.2021  28.04.2023  Die App "Mindable: Panikstörung und Agoraphobi...
# 21  06.02.2022  05.02.2023  neolexon Aphasie bietet Menschen mit Aphasie u...
# 22  03.07.2021  02.07.2023  Die App dient der Behandlung und Linderung ein...
# 23  10.10.2021  09.10.2023  Novego: Depressionen bewältigen ist ein psycho...
# 24  14.07.2022  13.07.2023  Bei optimune handelt es sich um eine DiGA für ...
# 25  03.10.2021  02.07.2023  Oviva Direkt für Adipositas ist die digitale T...
# 26  27.06.2022  26.06.2023  PINK! Coach ist eine digitale Anwendung, die z...
# 27  29.09.2022  28.09.2023  Die Sporlastic Medizinische Produkte GmbH stel...
# 28        None        None  Selfapy bietet Betroffenen mit einer Depressio...
# 29        None        None  Selfapy bietet weiblichen Patientinnen mit ein...
# 30  10.10.2022  09.08.2023  sinCephalea stellt eine leitliniengerechte Anf...
# 31        None        None  somnio ist eine digitale Anwendung zur Behandl...
# 32        None        None  velibra ist ein webbasiertes Programm für Pati...
# 33  15.04.2022  14.04.2023  Vitadio bei Diabetes Typ 2 ist eine DiGA, die ...
# 34        None        None  Die DiGA Vivira ist eine durch das BfArM endgü...
# 35        None        None  vorvida ist eine digitale Gesundheitsanwendung...
# 36        None        None  zanadio ist eine Anwendung, die weiblichen Pat...
#
#                                      indication_codes  \
# 0                                               [C50]
# 1                   [K58, K58.1, K58.2, K58.3, K58.8]
# 2                [M22.2, M22.4, M76.5, M79.66, S83.0]
# 3          [F32.0, F32.1, F32.2, F33.0, F33.1, F33.2]
# 4                        [F32.0, F32.1, F33.0, F33.1]
# 5                                               [G35]
# 6   [F32.0, F32.1, F32.2, F33.0, F33.1, F33.2, F34.1]
# 7                                               [N80]
# 8                                          [E10, E11]
# 9                                     [F40.01, F41.0]
# 10         [F45.40, F45.41, M54, M79.7, R52.1, R52.2]
# 11                                     [F51.0, G47.0]
# 12                                              [Z73]
# 13                                     [F52.5, F52.6]
# 14                     [F40.00, F40.01, F40.1, F41.0]
# 15                                     [J44.8, J44.9]
# 16                                            [H93.1]
# 17                                            [N48.4]
# 18                                              [M22]
# 19                                            [H93.1]
# 20                                     [F40.0, F41.0]
# 21                                     [R47.0, R48.2]
# 22                                            [F17.2]
# 23                [F32.0, F32.1, F33.0, F33.1, F34.1]
# 24                                              [C50]
# 25                                              [E66]
# 26                                              [C50]
# 27  [M17.0, M17.1, M17.2, M17.3, M17.4, M17.5, M17.9]
# 28                       [F32.0, F32.1, F33.0, F33.1]
# 29                                            [F41.1]
# 30                                     [G43.0, G43.1]
# 31                                            [F51.0]
# 32                      [F40.01, F40.1, F41.0, F41.1]
# 33                                              [E11]
# 34  [M42.0, M42.1, M42.9, M53.2, M53.8, M53.9, M54...
# 35                                     [F10.1, F10.2]
# 36                                   [E66.00, E66.01]
#
#                                      indication_names            price  \
# 0       [Bösartige Neubildung der Brustdrüse [Mamma]]           399.84
# 1   [Reizdarmsyndrom, Reizdarmsyndrom, Diarrhoe-pr...           718.20
# 2   [Krankheiten im Patellofemoralbereich, Chondro...           345.10
# 3   [Leichte depressive Episode, Mittelgradige dep...           210.00
# 4   [Leichte depressive Episode, Mittelgradige dep...  178.50 - 357.00
# 5   [Multiple Sklerose [Encephalomyelitis dissemin...           243.00
# 6   [Leichte depressive Episode, Mittelgradige dep...           535.49
# 7                                      [Endometriose]           598.95
# 8   [Diabetes mellitus, Typ 1, Diabetes mellitus, ...           222.99
# 9   [Agoraphobie: Mit Panikstörung, Panikstörung [...           599.00
# 10  [Anhaltende somatoforme Schmerzstörung, Chroni...           599.00
# 11  [Nichtorganische Insomnie, Ein- und Durchschla...           599.00
# 12  [Probleme mit Bezug auf Schwierigkeiten bei de...           235.00
# 13  [Nichtorganischer Vaginismus, Nichtorganische ...           599.00
# 14  [Agoraphobie: Ohne Angabe einer Panikstörung, ...           620.00
# 15  [Sonstige näher bezeichnete chronische obstruk...           415.00
# 16                                  [Tinnitus aurium]           189.00
# 17                   [Impotenz organischen Ursprungs]           656.88
# 18                          [Krankheiten der Patella]           119.00
# 19                                  [Tinnitus aurium]           449.00
# 20  [Agoraphobie, Panikstörung [episodisch paroxys...           576.00
# 21                   [Dysphasie und Aphasie, Apraxie]           487.90
# 22  [Psychische und Verhaltensstörungen durch Taba...  119.00 - 329.00
# 23  [Leichte depressive Episode, Mittelgradige dep...           249.00
# 24      [Bösartige Neubildung der Brustdrüse [Mamma]]           952.00
# 25                                       [Adipositas]           426.96
# 26      [Bösartige Neubildung der Brustdrüse [Mamma]]           535.50
# 27  [Primäre Gonarthrose, beidseitig, Sonstige pri...           784.21
# 28  [Leichte depressive Episode, Mittelgradige dep...           217.18
# 29                      [Generalisierte Angststörung]           479.52
# 30  [Migräne ohne Aura [Gewöhnliche Migräne], Migr...           690.00
# 31                         [Nichtorganische Insomnie]           224.99
# 32  [Agoraphobie: Mit Panikstörung, Soziale Phobie...           230.00
# 33                         [Diabetes mellitus, Typ 2]           499.80
# 34  [Juvenile Osteochondrose der Wirbelsäule, Oste...           239.96
# 35  [Psychische und Verhaltensstörungen durch Alko...           192.01
# 36  [Adipositas durch übermäßige Kalorienzufuhr: A...           499.80
#
#                                       property_values
# 0   [Keine Zusatzgeräte, Vertragsärztliche Leistun...
# 1   [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 2   [Keine Zusatzgeräte, Vertragsärztliche Leistun...
# 3   [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 4   [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 5   [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 6   [Keine Zusatzgeräte, Vertragsärztliche Leistun...
# 7   [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 8   [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 9   [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 10  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 11  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 12  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 13  [Zusatzgeräte optional, Keine vertragsärztlich...
# 14  [Zusatzgeräte enthalten, Vertragsärztliche Lei...
# 15  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 16  [Keine Zusatzgeräte, Vertragsärztliche Leistun...
# 17  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 18  [Keine Zusatzgeräte, Vertragsärztliche Leistun...
# 19  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 20  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 21  [Keine Zusatzgeräte, Vertragsärztliche Leistun...
# 22  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 23  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 24  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 25  [Keine Zusatzgeräte, Vertragsärztliche Leistun...
# 26  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 27  [Zusatzgeräte enthalten, Keine vertragsärztlic...
# 28  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 29  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 30  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 31  [Zusatzgeräte optional, Vertragsärztliche Leis...
# 32  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 33  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 34  [Keine Zusatzgeräte, Vertragsärztliche Leistun...
# 35  [Keine Zusatzgeräte, Keine vertragsärztlichen ...
# 36  [Zusatzgeräte optional, Vertragsärztliche Leis...

# %%
# remove [ ] from indication codes
df['indication_codes'] = df['indication_codes'].apply(lambda x: str(x).replace('[', '').replace(']', ''))
# remove ' from indication codes
df['indication_codes'] = df['indication_codes'].apply(lambda x: str(x).replace("'", ''))
# remove [ ] from property values
df['property_values'] = df['property_values'].apply(lambda x: str(x).replace('[', '').replace(']', '').replace("'", ''))
# remove [ ] from indication names
df['indication_names'] = df['indication_names'].apply(lambda x: str(x).replace('[', '').replace(']', '').replace("'", ''))

# %%
# save df to csv
df.to_csv('diga.csv', index=False)

# %%
# load df from csv
import pandas as pd
df = pd.read_csv('diga.csv')
df
# Out:
#                                              app_name  \
# 0                              CANKADO PRO-React Onco
# 1                              Cara Care für Reizdarm
# 2   companion patella powered by medi - proved by ...
# 3                                            deprexis
# 4                                    edupression.com®
# 5                                             elevida
# 6                            elona therapy Depression
# 7                                            Endo-App
# 8                 HelloBetter Diabetes und Depression
# 9                                   HelloBetter Panik
# 10         HelloBetter ratiopharm chronischer Schmerz
# 11                               HelloBetter Schlafen
# 12                     HelloBetter Stress und Burnout
# 13                        HelloBetter Vaginismus Plus
# 14                  Invirto- Die Therapie gegen Angst
# 15              Kaia COPD: Meine aktive COPD Therapie
# 16                                            Kalmeda
# 17                                       Kranus Edera
# 18                                            Mawendo
# 19  Meine Tinnitus App - Das digitale Tinnitus Cou...
# 20             Mindable: Panikstörung und Agoraphobie
# 21                                   neolexon Aphasie
# 22                             NichtraucherHelden-App
# 23                    Novego: Depressionen bewältigen
# 24                                           optimune
# 25                        Oviva Direkt für Adipositas
# 26                                        PINK! Coach
# 27                                            re.flex
# 28                Selfapys Online-Kurs bei Depression
# 29  Selfapys Online-Kurs bei Generalisierter Angst...
# 30                    sinCephalea - Migräneprophylaxe
# 31                                             somnio
# 32                                            velibra
# 33                                            Vitadio
# 34                                             Vivira
# 35                                            vorvida
# 36                                            zanadio
#
#                                        developer_info  \
# 0                           CANKADO GmbH, Deutschland
# 1                HiDoc Technologies GmbH, Deutschland
# 2                           PrehApp GmbH, Deutschland
# 3                                GAIA AG, Deutschland
# 4                               SOFY GmbH, Österreich
# 5                                GAIA AG, Deutschland
# 6                      Elona Health GmbH, Deutschland
# 7                       Endo Health GmbH, Deutschland
# 8   GET.ON Institut für Online Gesundheitstraining...
# 9   GET.ON Institut für Online Gesundheitstraining...
# 10  GET.ON Institut für Online Gesundheitstraining...
# 11  GET.ON Institut für Online Gesundheitstraining...
# 12  GET.ON Institut für Online Gesundheitstraining...
# 13  GET.ON Institut für Online Gesundheitstraining...
# 14                       Sympatient GmbH, Deutschland
# 15             kaia health software GmbH, Deutschland
# 16                          mynoise GmbH, Deutschland
# 17                    Kranus Health GmbH, Deutschland
# 18                          Mawendo GmbH, Deutschland
# 19                         Sonormed GmbH, Deutschland
# 20                  Mindable Health GmbH, Deutschland
# 21                          Limedix GmbH, Deutschland
# 22               NichtraucherHelden GmbH, Deutschland
# 23                      IVPNetworks GmbH, Deutschland
# 24                               GAIA AG, Deutschland
# 25  Oviva AG (Zweigniederlassung Deutschland) , De...
# 26            PINK gegen Brustkrebs GmbH, Deutschland
# 27                    Kineto Tech Rehab SRL, Rumänien
# 28                          Selfapy GmbH, Deutschland
# 29                          Selfapy GmbH, Deutschland
# 30                          Perfood GmbH, Deutschland
# 31                      mementor DE GmbH, Deutschland
# 32                               GAIA AG, Deutschland
# 33                         Vitadio s.r.o., Tschechien
# 34                Vivira Health Lab GmbH, Deutschland
# 35                               GAIA AG, Deutschland
# 36                          aidhere GmbH, Deutschland
#
#                                          website_info             app_status  \
# 0                         partners.cankado.com/about/  vorläufig aufgenommen
# 1                                 cara.care/de/about/  vorläufig aufgenommen
# 2                                          prehapp.de  vorläufig aufgenommen
# 3                                  gaia-group.com/de/  Dauerhaft aufgenommen
# 4                                    edupression.com/  vorläufig aufgenommen
# 5                                  gaia-group.com/de/  Dauerhaft aufgenommen
# 6                                    www.elona.health  vorläufig aufgenommen
# 7                               diga.endometriose.app  vorläufig aufgenommen
# 8                                     hellobetter.de/  Dauerhaft aufgenommen
# 9                                     hellobetter.de/  Dauerhaft aufgenommen
# 10                                 www.hellobetter.de  vorläufig aufgenommen
# 11                                    hellobetter.de/  vorläufig aufgenommen
# 12                                    hellobetter.de/  Dauerhaft aufgenommen
# 13                                    hellobetter.de/  Dauerhaft aufgenommen
# 14                                     www.invirto.de  Dauerhaft aufgenommen
# 15                                     kaiahealth.de/  vorläufig aufgenommen
# 16                                     www.kalmeda.de  Dauerhaft aufgenommen
# 17                               www.kranushealth.com  vorläufig aufgenommen
# 18                                  diga.mawendo.com/  vorläufig aufgenommen
# 19                               www.sonormed.com/de/  vorläufig aufgenommen
# 20                                www.mindable.health  vorläufig aufgenommen
# 21                                       neolexon.de/  vorläufig aufgenommen
# 22                         www.nichtraucherhelden.de/  vorläufig aufgenommen
# 23                                www.ivpnetworks.de/  vorläufig aufgenommen
# 24                                 gaia-group.com/de/  vorläufig aufgenommen
# 25  oviva.com/de/de/oviva-direkt/rechtliche-hinweise/  vorläufig aufgenommen
# 26                             www.pink-brustkrebs.de  vorläufig aufgenommen
# 27                           www.sporlastic.de/reflex  vorläufig aufgenommen
# 28                                     www.selfapy.de  Dauerhaft aufgenommen
# 29                                    www.selfapy.com  Dauerhaft aufgenommen
# 30                                    www.perfood.de/  vorläufig aufgenommen
# 31                                    www.mementor.de  Dauerhaft aufgenommen
# 32                                 gaia-group.com/de/  Dauerhaft aufgenommen
# 33                                        vitadio.de/  vorläufig aufgenommen
# 34                                     www.vivira.com  Dauerhaft aufgenommen
# 35                                 gaia-group.com/de/  Dauerhaft aufgenommen
# 36                                        aidhere.de/  Dauerhaft aufgenommen
#
#     start_date    end_date                                    app_description  \
# 0   03.05.2021  02.05.2023  PRO-React Onco ist eine Web- und App-basierte ...
# 1   26.12.2021  25.11.2023  Cara Care für Reizdarm ist eine digitale Gesun...
# 2   04.10.2021  03.03.2023  companion patella powered by medi - proved by ...
# 3          NaN         NaN  deprexis ist ein interaktives onlinebasiertes ...
# 4   26.12.2022  25.08.2023  Die DiGA edupression.com® besteht aus dem Medi...
# 5          NaN         NaN  elevida ist eine digitale Gesundheitsanwendung...
# 6   26.12.2022  25.12.2023  elona therapy Depression ist die digitale Gesu...
# 7   09.10.2022  08.10.2023  Die Endo-App ist ein digitales Medizinprodukt ...
# 8          NaN         NaN  HelloBetter Diabetes und Depression ist ein in...
# 9          NaN         NaN  HelloBetter Panik ist ein interaktives psychol...
# 10  18.12.2021  17.07.2023  HelloBetter ratiopharm chronischer Schmerz ist...
# 11  18.12.2022  17.12.2023  HelloBetter Schlafen ist ein interaktives psyc...
# 12         NaN         NaN  HelloBetter Stress und Burnout ist ein interak...
# 13         NaN         NaN  HelloBetter Vaginismus Plus ist eine digitale ...
# 14         NaN         NaN  Invirto ermöglicht Menschen mit einer Agorapho...
# 15  26.12.2022  25.12.2023  Kaia COPD ist eine gemeinsam mit Lungenfachärz...
# 16         NaN         NaN  Diese DiGA bietet Patientinnen und Patienten (...
# 17  18.12.2021  17.04.2023  Kranus Edera ist eine digitale Gesundheitsanwe...
# 18  09.08.2021  08.08.2023  Mawendo stellt Trainingsprogramme mit Übungsvi...
# 19  06.03.2022  05.03.2023  Meine Tinnitus App - Das digitale Tinnitus Cou...
# 20  29.04.2021  28.04.2023  Die App "Mindable: Panikstörung und Agoraphobi...
# 21  06.02.2022  05.02.2023  neolexon Aphasie bietet Menschen mit Aphasie u...
# 22  03.07.2021  02.07.2023  Die App dient der Behandlung und Linderung ein...
# 23  10.10.2021  09.10.2023  Novego: Depressionen bewältigen ist ein psycho...
# 24  14.07.2022  13.07.2023  Bei optimune handelt es sich um eine DiGA für ...
# 25  03.10.2021  02.07.2023  Oviva Direkt für Adipositas ist die digitale T...
# 26  27.06.2022  26.06.2023  PINK! Coach ist eine digitale Anwendung, die z...
# 27  29.09.2022  28.09.2023  Die Sporlastic Medizinische Produkte GmbH stel...
# 28         NaN         NaN  Selfapy bietet Betroffenen mit einer Depressio...
# 29         NaN         NaN  Selfapy bietet weiblichen Patientinnen mit ein...
# 30  10.10.2022  09.08.2023  sinCephalea stellt eine leitliniengerechte Anf...
# 31         NaN         NaN  somnio ist eine digitale Anwendung zur Behandl...
# 32         NaN         NaN  velibra ist ein webbasiertes Programm für Pati...
# 33  15.04.2022  14.04.2023  Vitadio bei Diabetes Typ 2 ist eine DiGA, die ...
# 34         NaN         NaN  Die DiGA Vivira ist eine durch das BfArM endgü...
# 35         NaN         NaN  vorvida ist eine digitale Gesundheitsanwendung...
# 36         NaN         NaN  zanadio ist eine Anwendung, die weiblichen Pat...
#
#                                      indication_codes  \
# 0                                                 C50
# 1                     K58, K58.1, K58.2, K58.3, K58.8
# 2                  M22.2, M22.4, M76.5, M79.66, S83.0
# 3            F32.0, F32.1, F32.2, F33.0, F33.1, F33.2
# 4                          F32.0, F32.1, F33.0, F33.1
# 5                                                 G35
# 6     F32.0, F32.1, F32.2, F33.0, F33.1, F33.2, F34.1
# 7                                                 N80
# 8                                            E10, E11
# 9                                       F40.01, F41.0
# 10           F45.40, F45.41, M54, M79.7, R52.1, R52.2
# 11                                       F51.0, G47.0
# 12                                                Z73
# 13                                       F52.5, F52.6
# 14                       F40.00, F40.01, F40.1, F41.0
# 15                                       J44.8, J44.9
# 16                                              H93.1
# 17                                              N48.4
# 18                                                M22
# 19                                              H93.1
# 20                                       F40.0, F41.0
# 21                                       R47.0, R48.2
# 22                                              F17.2
# 23                  F32.0, F32.1, F33.0, F33.1, F34.1
# 24                                                C50
# 25                                                E66
# 26                                                C50
# 27    M17.0, M17.1, M17.2, M17.3, M17.4, M17.5, M17.9
# 28                         F32.0, F32.1, F33.0, F33.1
# 29                                              F41.1
# 30                                       G43.0, G43.1
# 31                                              F51.0
# 32                        F40.01, F40.1, F41.0, F41.1
# 33                                                E11
# 34  M42.0, M42.1, M42.9, M53.2, M53.8, M53.9, M54....
# 35                                       F10.1, F10.2
# 36                                     E66.00, E66.01
#
#                                      indication_names            price  \
# 0           Bösartige Neubildung der Brustdrüse Mamma           399.84
# 1   Reizdarmsyndrom, Reizdarmsyndrom, Diarrhoe-prä...           718.20
# 2   Krankheiten im Patellofemoralbereich, Chondrom...           345.10
# 3   Leichte depressive Episode, Mittelgradige depr...           210.00
# 4   Leichte depressive Episode, Mittelgradige depr...  178.50 - 357.00
# 5     Multiple Sklerose Encephalomyelitis disseminata           243.00
# 6   Leichte depressive Episode, Mittelgradige depr...           535.49
# 7                                        Endometriose           598.95
# 8   Diabetes mellitus, Typ 1, Diabetes mellitus, T...           222.99
# 9   Agoraphobie: Mit Panikstörung, Panikstörung ep...           599.00
# 10  Anhaltende somatoforme Schmerzstörung, Chronis...           599.00
# 11  Nichtorganische Insomnie, Ein- und Durchschlaf...           599.00
# 12  Probleme mit Bezug auf Schwierigkeiten bei der...           235.00
# 13  Nichtorganischer Vaginismus, Nichtorganische D...           599.00
# 14  Agoraphobie: Ohne Angabe einer Panikstörung, A...           620.00
# 15  Sonstige näher bezeichnete chronische obstrukt...           415.00
# 16                                    Tinnitus aurium           189.00
# 17                     Impotenz organischen Ursprungs           656.88
# 18                            Krankheiten der Patella           119.00
# 19                                    Tinnitus aurium           449.00
# 20  Agoraphobie, Panikstörung episodisch paroxysma...           576.00
# 21                     Dysphasie und Aphasie, Apraxie           487.90
# 22  Psychische und Verhaltensstörungen durch Tabak...  119.00 - 329.00
# 23  Leichte depressive Episode, Mittelgradige depr...           249.00
# 24          Bösartige Neubildung der Brustdrüse Mamma           952.00
# 25                                         Adipositas           426.96
# 26          Bösartige Neubildung der Brustdrüse Mamma           535.50
# 27  Primäre Gonarthrose, beidseitig, Sonstige prim...           784.21
# 28  Leichte depressive Episode, Mittelgradige depr...           217.18
# 29                        Generalisierte Angststörung           479.52
# 30  Migräne ohne Aura Gewöhnliche Migräne, Migräne...           690.00
# 31                           Nichtorganische Insomnie           224.99
# 32  Agoraphobie: Mit Panikstörung, Soziale Phobien...           230.00
# 33                           Diabetes mellitus, Typ 2           499.80
# 34  Juvenile Osteochondrose der Wirbelsäule, Osteo...           239.96
# 35  Psychische und Verhaltensstörungen durch Alkoh...           192.01
# 36  Adipositas durch übermäßige Kalorienzufuhr: Ad...           499.80
#
#                                       property_values
# 0   Keine Zusatzgeräte, Vertragsärztliche Leistung...
# 1   Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 2   Keine Zusatzgeräte, Vertragsärztliche Leistung...
# 3   Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 4   Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 5   Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 6   Keine Zusatzgeräte, Vertragsärztliche Leistung...
# 7   Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 8   Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 9   Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 10  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 11  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 12  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 13  Zusatzgeräte optional, Keine vertragsärztliche...
# 14  Zusatzgeräte enthalten, Vertragsärztliche Leis...
# 15  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 16  Keine Zusatzgeräte, Vertragsärztliche Leistung...
# 17  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 18  Keine Zusatzgeräte, Vertragsärztliche Leistung...
# 19  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 20  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 21  Keine Zusatzgeräte, Vertragsärztliche Leistung...
# 22  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 23  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 24  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 25  Keine Zusatzgeräte, Vertragsärztliche Leistung...
# 26  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 27  Zusatzgeräte enthalten, Keine vertragsärztlich...
# 28  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 29  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 30  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 31  Zusatzgeräte optional, Vertragsärztliche Leist...
# 32  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 33  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 34  Keine Zusatzgeräte, Vertragsärztliche Leistung...
# 35  Keine Zusatzgeräte, Keine vertragsärztlichen L...
# 36  Zusatzgeräte optional, Vertragsärztliche Leist...

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('multi-qa-MiniLM-L6-cos-v1')

query_embedding = model.encode('How big is London')
passage_embedding1 = model.encode(['London has 9,787,426 inhabitants at the 2011 census',
                                  'London is known for its finacial district'])

passage_embedding2 = model.encode(['The greatest pleasure of a man is his worth and his honor, they way his compatriots look at thim.'])
passage_embedding3 = model.encode(['London is of similiar size to Berlin'])

print("Similarity:", util.dot_score(query_embedding, passage_embedding1))
# Out:
# Similarity: tensor([[0.5472, 0.6330]])

# %%
query = model.encode('rückenschmerzen')
passage = model.encode(['HelloBetter ratiopharm chronischer Schmerz ist ein interaktives psychologisches Online-Programm zur anhaltenden Reduktion der Schmerzbeeinträchtigung bei Menschen mit chronischen Schmerzen. Neben fundierter Psychoedukation mittels Texten, Videos und Audios, erlernen Betroffene wirksame Strategien der Akzeptanz- und Commitment-Therapie (ACT), die eine Weiterentwicklung der kognitiven Verhaltenstherapie (KVT) darstellt. Diese Strategien können durch praktische Übungen in den Alltag übertragen werden.', 'HelloBetter Schlafen ist ein interaktives psychologisches Therapieprogramm zur Reduktion insomnischer Beschwerden. Das Online-Programm basiert auf der kognitiven Verhaltenstherapie für Insomnie (KVT-I) und wurde von Expertinnen und Experten aus der Wissenschaft, Psychologie und Psychotherapie sowie gemeinsam mit Betroffenen entwickelt. Neben fundierter Psychoedukation vermittelt das Online-Programm wirksame Strategien aus der kognitiven Verhaltenstherapie nach dem aktuellsten Stand wissenschaftlicher Erkenntnisse. Dazu gehören unter anderem Schlafhygiene, Bettzeitverkürzung, Stimuluskontrolle, kognitive Strategien, Entspannungsverfahren, eine Rückfallprophylaxe sowie ein fortlaufendes Online-Tagebuch.'])
print("Similarity:", util.dot_score(query, passage))
# Out:
# Similarity: tensor([[0.2911, 0.2449]])

# %%
model = SentenceTransformer('Sahajtomar/German-semantic')
query = model.encode('rückenschmerzen')
passage = model.encode(['HelloBetter ratiopharm chronischer Schmerz ist ein interaktives psychologisches Online-Programm zur anhaltenden Reduktion der Schmerzbeeinträchtigung bei Menschen mit chronischen Schmerzen. Neben fundierter Psychoedukation mittels Texten, Videos und Audios, erlernen Betroffene wirksame Strategien der Akzeptanz- und Commitment-Therapie (ACT), die eine Weiterentwicklung der kognitiven Verhaltenstherapie (KVT) darstellt. Diese Strategien können durch praktische Übungen in den Alltag übertragen werden.', 'HelloBetter Schlafen ist ein interaktives psychologisches Therapieprogramm zur Reduktion insomnischer Beschwerden. Das Online-Programm basiert auf der kognitiven Verhaltenstherapie für Insomnie (KVT-I) und wurde von Expertinnen und Experten aus der Wissenschaft, Psychologie und Psychotherapie sowie gemeinsam mit Betroffenen entwickelt. Neben fundierter Psychoedukation vermittelt das Online-Programm wirksame Strategien aus der kognitiven Verhaltenstherapie nach dem aktuellsten Stand wissenschaftlicher Erkenntnisse. Dazu gehören unter anderem Schlafhygiene, Bettzeitverkürzung, Stimuluskontrolle, kognitive Strategien, Entspannungsverfahren, eine Rückfallprophylaxe sowie ein fortlaufendes Online-Tagebuch.'])
print("Similarity:", util.dot_score(query, passage))
# Out:
# Similarity: tensor([[108.3415,  94.2840]])

# %%
from transformers import AutoTokenizer, AutoModel

# Initialize the BERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained('bert-base-uncased')

# Tokenize and encode the text data
encoded_text = tokenizer.batch_encode_plus(df['text'], return_tensors='pt')
encoded_text = model(**encoded_text)[0]

# Find the most similar entries in the dataframe using cosine similarity
query_vector = encoded_text[0]  # select the first entry as the query
similarity = encoded_text @ query_vector.T  # calculate the cosine similarity
most_similar_index = similarity.argmax().item()  # find the index of the most similar entry
most_similar_entry = df.iloc[most_similar_index]  # retrieve the most similar entry from the dataframe

print(f'Most similar entry: {most_similar_entry["text"]}')
